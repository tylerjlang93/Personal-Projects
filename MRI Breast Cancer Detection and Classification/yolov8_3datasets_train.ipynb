# %% [markdown]
# # Train YOLOv8 Model for Segmentation Task Only

# %%
import os
import sys

import torch
import ultralytics
from ultralytics import YOLO

ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.142  Python-3.10.2 torch-2.0.1+cpu CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# Setup complete  (8 CPUs, 15.7 GB RAM, 407.9/952.6 GB disk)

# %% [markdown]
# Train on All Datasets (AI+, BUSI, OASBUD)
#     with no image enhancement

# %%
# Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8s.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8m.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8l.pt')  # load a pretrained model (recommended for training)
# model = YOLO('yolov8x.pt')  # load a pretrained model (recommended for training)

model.train(data='./yolov8_3datasets_train.yaml',   # Dataset with CLAHE Enhancement, Best Practice
# model.train(data='./aiplus_clahe_default.yaml',   # Dataset with CLAHE Enhancement, Best Practice
            lr0=0.001, 
            epochs=100,
            # batch=32,
            batch=16,  
            imgsz=160,
            optimizer='SGD', 
            task='detect')
# Out:
# Ultralytics YOLOv8.0.142  Python-3.10.2 torch-2.0.1+cpu CPU (11th Gen Intel Core(TM) i7-1185G7 3.00GHz)
# ...

# %%
# load the best recent run
trained_model = YOLO('./Trained_Models/best_yol_seg3.pt')

# output the validation performance
trained_model.val()

# run it against the new data
results = trained_model('./Data/Aiplus_yoloformat_images/images/val')
# Out:
# image 1/180 C:\GTMS Projects\Practicum\AIPlus_BC_Practicum\Data\Aiplus_yoloformat_images\images\val\04A195C7193647B599073C0FD2EF4D7D_2620171 (2).jpg: 128x160 1 tumor, 25.3ms
# image 2/180 C:\GTMS Projects\Practicum\AIPlus_BC_Practicum\Data\Aiplus_yoloformat_images\images\val\20170807080027.jpg: 160x160 1 tumor, 25.0ms
# image 3/180 C:\GTMS Projects\Practicum\AIPlus_BC_Practicum\Data\Aiplus_yoloformat_images\images\val\20171205153049a.jpg: 160x128 1 tumor, 18.0ms
# image 4/180 C:\GTMS Projects\Practicum\AIPlus_BC_Practicum\Data\Aiplus_yoloformat_images\images\val\20180101104442.jpg: 160x160 1 tumor, 15.0ms
# image 5/180 C:\GTMS Projects\Practicum\AIPlus_BC_Practicum\Data\Aiplus_yoloformat_images\images\val\20180101104635.jpg: 160x160 1 tumor, 17.0ms
# image 6/180 C:\GTMS Projects\Practicum\AIPlus_BC_Practicum\Data\Aiplus_yoloformat_images\images\val\20180114161534.jpg: 128x160 1 tumor, 15.0ms
# ...
